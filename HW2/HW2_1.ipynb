# %%
import h5py 
import numpy as np
#import math

f = h5py.File('mnist_testdata.hdf5','r') 
#f=h5py.File('mnist_network_params.hdf5','r')
list(f.keys())
#list(f1.keys())
# Out:
# ['xdata', 'ydata']

# %%
xtrain=f['xdata']
#ytrain=f['ydata']

# %%
f1 = h5py.File('mnist_network_params.hdf5','r') 
w1=f1['W1']
w2=f1['W2']
w3=f1['W3']
b1=f1['b1']
b2=f1['b2']
b3=f1['b3']

# %%
print(w1.shape,w2.shape,w3.shape,b1.shape,b2.shape,b3.shape)
w1=np.array(w1)
w2=np.array(w2)
w3=np.array(w3)
b1=np.array(b1)
b2=np.array(b2)
b3=np.array(b3)
xtrain=np.array(xtrain)
#ytrain=np.array(ytrain)
# Out:
# (200, 784) (100, 200) (10, 100) (200,) (100,) (10,)

# %%
def relu(x):
    return np.maximum(x, 0)

# %%
def Softmax(x):
    exp_scores = np.exp(x)
    out = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    return out

# %%
def feed_forward(x):
    z1 = x@w1.transpose() + b1
    a1 = relu(z1)
    z2 = a1@w2.transpose() + b2
    a2 = relu(z2)
    z3 = a2@w3.transpose() + b3
    a3 = relu(z3)
    out = Softmax(a3)
    return a1,a2,a3,out

# %%
pred=feed_forward(xtrain)
pred_result=pred[3]
print(pred[3][0:3,:])
# Out:
# [[4.8460596e-09 4.8460596e-09 9.3678693e-07 3.7119484e-05 4.8460596e-09
#   4.8460596e-09 4.8460596e-09 9.9996161e-01 4.8460596e-09 2.8118322e-07]
#  [9.0599028e-10 4.7129006e-07 9.9999839e-01 1.0429526e-06 9.0599028e-10
#   9.0599028e-10 2.1672317e-08 9.0599028e-10 1.6367314e-07 9.0599028e-10]
#  [3.6753838e-05 9.9914736e-01 9.5336167e-05 3.6753838e-05 3.6753838e-05
#   3.6753838e-05 3.6753838e-05 1.4126032e-04 3.9555319e-04 3.6753838e-05]]

# %%
num=0
n_iter=xtrain.shape[0]
pred_result=np.zeros((n_iter,10),float)
pred_label=np.zeros((n_iter,1),float)
for i in range (0,n_iter):
    pred_result[i,:]=pred[3][i,:]
    label=np.where(pred_result[i,:]==np.max(pred_result[i,:]))   # find label for each predict data
    pred_label[i,0]=label[0][0]
#    train_result=ytrain[i,:]
#    index_1=train_result.nonzero()[0]
#    num_1=pred_result[index_1[0]]
#    if np.equal(pred_result.max(0),num_1):
#        num=num+1    
#print(num)
#print(num_false)

# %%
output = []
for i in range(0,n_iter):
    output.append({
      "activations": pred_result[i,:].tolist(),
      "index": i,
      "classification": int(pred_result[i,:].argmax())
    })

import json
print("AUTOGRADE: %s" % (json.dumps(output)))
# Out:
# AUTOGRADE: [{"activations": [4.84605955364259e-09, 4.84605955364259e-09, 9.36786932470568e-07, 3.711948374984786e-05, 4.84605955364259e-09, 4.84605955364259e-09, 4.84605955364259e-09, 0.9999616146087646, 4.84605955364259e-09, 2.811832189308916e-07], "index": 0, "classification": 7}, {"activations": [9.059902827956989e-10, 4.712900647518836e-07, 0.9999983906745911, 1.042952590069035e-06, 9.059902827956989e-10, 9.059902827956989e-10, 2.1672317274123998e-08, 9.059902827956989e-10, 1.6367313548926177e-07, 9.059902827956989e-10], "index": 1, "classification": 2}, {"activations": [3.6753837775904685e-05, 0.999147355556488, 9.533616685075685e-05, 3.6753837775904685e-05, 3.6753837775904685e-05, 3.6753837775904685e-05, 3.6753837775904685e-05, 0.00014126031601335853, 0.00039555318653583527, 3.6753837775904685e-05], "index": 2, "classification": 1}, {"activations": [0.9999994039535522, 8.858521027832467e-09, 3.4345720223427634e-07, 8.858521027832467e-09, 8.858521027832467e-09, 8.858521027832467e-09, 2.1156063212401932e-07, 8.858521027832467e-09, 8.858521027832467e-09, 8.858521027832467e-09], "index": 3, "classification": 0}, {"activations": [4.009848453279119e-08, 4.009848453279119e-08, 6.366621363440572e-08, 4.009848453279119e-08, 0.999965488910675, 4.009848453279119e-08, 4.009848453279119e-08, 9.226469614986854e-07, 4.009848453279119e-08, 3.326537989778444e-05], "index": 4, "classification": 4}, {"activations": [1.5266764421539847e-06, 0.9994694590568542, 1.5266764421539847e-06, 1.5266764421539847e-06, 1.5266764421539847e-06, 1.5266764421539847e-06, 1.5266764421539847e-06, 0.0005173800163902342, 2.4428645701846108e-06, 1.5266764421539847e-06], "index": 5, "classification": 1}, {"activations": [8.012769825427313e-08, 8.012769825427313e-08, 8.012769825427313e-08, 8.012769825427313e-08, 0.999926745891571, 1.0231694602680363e-07, 8.012769825427313e-08, 4.166952010109526e-07, 1.3445656804833561e-05, 5.891853288630955e-05], "index": 6, "classification": 4}, {"activations": [4.148221250943607e-06, 4.148221250943607e-06, 9.92736477201106e-06, 0.0001777829456841573, 8.940955922298599e-06, 4.148221250943607e-06, 4.148221250943607e-06, 0.00011934723443118855, 4.148221250943607e-06, 0.9996632933616638], "index": 7, "classification": 9}, {"activations": [1.6720987332519144e-05, 1.6720987332519144e-05, 0.0002219846355728805, 1.6720987332519144e-05, 1.6720987332519144e-05, 0.19148270785808563, 0.8079310655593872, 1.6720987332519144e-05, 0.00026396289467811584, 1.6720987332519144e-05], "index": 8, "classification": 6}, {"activations": [2.8901443016593475e-08, 2.8901443016593475e-08, 2.8901443016593475e-08, 1.8628961697686464e-06, 0.00032816475140862167, 2.8901443016593475e-08, 2.8901443016593475e-08, 0.00028762483270838857, 1.1663055374810938e-06, 0.9993810653686523], "index": 9, "classification": 9}, {"activations": [0.9999969601631165, 9.090224750707421e-08, 2.907969246734865e-06, 2.073379512523843e-08, 2.073379512523843e-08, 2.073379512523843e-08, 2.3121646819390662e-08, 2.073379512523843e-08, 2.073379512523843e-08, 2.073379512523843e-08], "index": 10, "classification": 0}, {"activations": [1.1284618040008354e-06, 9.76293534904471e-08, 5.003736305297934e-07, 9.76293534904471e-08, 9.76293534904471e-08, 9.76293534904471e-08, 0.999681830406189, 9.76293534904471e-08, 0.0003159674524795264, 9.76293534904471e-08], "index": 11, "classification": 6}, {"activations": [1.50097321238718e-08, 1.50097321238718e-08, 1.50097321238718e-08, 1.7974924659824865e-08, 4.506329673859e-07, 1.6533544311414516e-08, 1.50097321238718e-08, 1.50097321238718e-08, 6.911339767157187e-08, 0.9999994039535522], "index": 12, "classification": 9}, {"activations": [0.9999951720237732, 4.645948958881263e-09, 6.524602191859685e-09, 4.645948958881263e-09, 4.645948958881263e-09, 4.645948958881263e-09, 4.645948958881263e-09, 4.783235453942325e-06, 4.645948958881263e-09, 1.1850302961136094e-08], "index": 13, "classification": 0}, {"activations": [1.206487695526448e-06, 0.9999790191650391, 1. ...
